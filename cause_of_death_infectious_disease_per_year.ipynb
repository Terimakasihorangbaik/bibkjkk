# %%
import pandas as pd

df = pd.read_csv('data/cause_of_death_indonesia_clean.csv')

df
# Out:
#                                 Cause                           Type  Year  \
# 0            Tsunami Aceh (Meninggal)                   Bencana Alam  2004
# 1               Tsunami Aceh (Hilang)                   Bencana Alam  2004
# 2              Kecelakaan Lalu Lintas  Bencana Non Alam dan Penyakit  2010
# 3     Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit  2008
# 4    COVID-19 (per tanggal 24/4/2021)  Bencana Non Alam dan Penyakit  2021
# ..                                ...                            ...   ...
# 612                           Rubella  Bencana Non Alam dan Penyakit  2006
# 613                           Tsunami                   Bencana Alam  2019
# 614          Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2016
# 615          Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2017
# 616          Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit  2019
#
# ...

# %%
df = df[(df['Type'] == 'Bencana Non Alam dan Penyakit') & (~df['Cause'].str.contains('kecelakaan', case=False, regex=False)) & (~df['Cause'].str.contains('kebakaran', case=False, regex=False)) & (~df['Cause'].str.contains('teknologi', case=False, regex=False))].reset_index()

df
# Out:
#      index                             Cause                           Type  \
# 0        3   Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# 1        4  COVID-19 (per tanggal 24/4/2021)  Bencana Non Alam dan Penyakit
# 2        5                          COVID-19  Bencana Non Alam dan Penyakit
# 3        6   Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# 4        7   Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# ..     ...                               ...                            ...
# 425    607                       Ledakan Bom  Bencana Non Alam dan Penyakit
# 426    612                           Rubella  Bencana Non Alam dan Penyakit
# 427    614          Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit
# 428    615          Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit
# 429    616          Wabah Penyakit (Epidemi)  Bencana Non Alam dan Penyakit
#
#      Year  Data Redundancy  Total Deaths  \
# ...

# %%
df = df[df['Total Deaths'] != 0]

df
# Out:
#      index                             Cause                           Type  \
# 0        3   Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# 1        4  COVID-19 (per tanggal 24/4/2021)  Bencana Non Alam dan Penyakit
# 2        5                          COVID-19  Bencana Non Alam dan Penyakit
# 3        6   Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# 4        7   Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# ..     ...                               ...                            ...
# 379    517                           Difteri  Bencana Non Alam dan Penyakit
# 380    518                           Difteri  Bencana Non Alam dan Penyakit
# 381    524                       KLB Antraks  Bencana Non Alam dan Penyakit
# 382    525                        KLB Campak  Bencana Non Alam dan Penyakit
# 383    526                 KLB Leptospirosis  Bencana Non Alam dan Penyakit
#
#      Year  Data Redundancy  Total Deaths  \
# ...

# %%
df.loc[df['Cause'].str.startswith('KLB '), 'Cause'] = df.loc[df['Cause'].str.startswith('KLB'), 'Cause'].str.replace('KLB ', '')

# %%
df['Cause'].unique()
# Out:
# array(['Penyakit Sistem Sirkulasi Darah',
#        'COVID-19 (per tanggal 24/4/2021)', 'COVID-19',
#        'Penyakit Infeksi & Parasit Tertentu', 'Tuberkulosis',
#        'Kondisi Tertentu yang bermula pada masa Perinatal',
#        'Penyakit Sistem Napas', 'Penyakit Sistem Cerna',
#        'Cedera, Keracunan, dan Akibat Sebab Luar Tertentu Lainnya',
#        'Penyakit Endokrin, Nutrisi, dan Metabolik',
#        'Infeksi Saluran Napas Bagian Atas Akut Lainnya', 'Neoplasma',
#        'Stroke tidak menyebut pendarahan atau infark',
#        'Penyakit Sistem Kemih Kelamin',
#        'Gejala, Tanda & Penemuan Laboratorium, Klinik Abnormal YTK',
#        'Diare & gastroenteritis Oleh penyebab infeksi tertentu (kolitis infeksi)',
#        'Tuberkulosis paru', 'Perdarahan intrakranial',
#        'Malaria (termasuk semua malaria)', 'TB Paru BTA Positif',
#        'TB Paru', 'Penyakit Susunan Syaraf', 'Pneumonia', 'Septisemia',
#        'Gagal ginjal lainnya', 'Cedera intrakranial',
# ...

# %%
antraks = df[df['Cause'].str.contains('Antraks', case=False)]

new_antraks = antraks.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_antraks.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Antraks', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Antraks', case=False), 'Cause'] = 'Antraks'

# %%
campak = df[df['Cause'].str.contains('Campak', case=False)]

new_campak = campak.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_campak.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Campak', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Campak', case=False), 'Cause'] = 'Campak'

# %%
cikungunya = df[df['Cause'].str.contains('Cikungunya', case=True)]

new_cikungunya = cikungunya.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_cikungunya.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Cikungunya', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Cikungunya', case=False), 'Cause'] = 'Cikungunya'

# %%
difteri = df[df['Cause'].str.contains('Difteri', case=False)]

new_difteri = difteri.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_difteri.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Difteri', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Difteri', case=False), 'Cause'] = 'Difteri'

# %%
gastroenteritis = df[df['Cause'].str.contains('Gastroenteritis', case=False)]

new_gastroenteritis = gastroenteritis.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_gastroenteritis.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Gastroenteritis', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Gastroenteritis', case=False), 'Cause'] = 'Gastroenteritis'

# %%
df.loc[df['Cause'] == ('KLB Hepatitis'), 'Cause'] = 'Hepatitis A'

# %%
df.loc[df['Cause'].str.contains('Covid', case=False), 'Cause'] = 'COVID-19'

# %%
malaria = df[df['Cause'].str.contains('Malaria', case=False)]

new_malaria = malaria.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_malaria.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Malaria', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Malaria', case=False), 'Cause'] = 'Malaria'

# %%
leptospirosis = df[df['Cause'].str.contains('Leptospirosis', case=False)]

new_leptospirosis = leptospirosis.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_leptospirosis.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Leptospirosis', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Leptospirosis', case=False), 'Cause'] = 'Leptospirosis'

# %%
rabies = df[df['Cause'].str.contains('Rabies', case=False)]

new_rabies = malaria.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_rabies.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Rabies', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Rabies', case=False), 'Cause'] = 'Rabies'

# %%
rubella = df[df['Cause'].str.contains('Rubella', case=False)]

new_rubella = rubella.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_rubella.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Rubella', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Rubella', case=False), 'Cause'] = 'Rubella'

# %%
tuberkulosis = df[df['Cause'].str.contains('Tuberkulosis', case=False)]

new_tuberkulosis = tuberkulosis.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_tuberkulosis.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Tuberkulosis', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Tuberkulosis', case=False), 'Cause'] = 'Tuberkulosis'

# %%
db = df[df['Cause'].str.contains('Demam berdarah', case=False)]

new_db = db.groupby('Year')['Total Deaths'].sum().reset_index()

for index, row in new_db.iterrows():
   year = row['Year']
   total_deaths = row['Total Deaths']
   df.loc[(df['Cause'].str.contains('Demam berdarah', case=False)) & (df['Year'] == year), 'Total Deaths'] = total_deaths

df.loc[df['Cause'].str.contains('Demam berdarah', case=False), 'Cause'] = 'Demam Berdarah'

# %%
df.drop_duplicates(subset=['Cause', 'Year'], keep='first', inplace=True)
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_28572\1052869635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Cause', 'Year'], keep='first', inplace=True)

# %%
df
# Out:
#      index                            Cause                           Type  \
# 0        3  Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# 1        4                         COVID-19  Bencana Non Alam dan Penyakit
# 2        5                         COVID-19  Bencana Non Alam dan Penyakit
# 3        6  Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# 4        7  Penyakit Sistem Sirkulasi Darah  Bencana Non Alam dan Penyakit
# ..     ...                              ...                            ...
# 374    511     Avian Influenza (Flu Burung)  Bencana Non Alam dan Penyakit
# 375    512                      Batuk Rejan  Bencana Non Alam dan Penyakit
# 376    514                           Campak  Bencana Non Alam dan Penyakit
# 377    515                           Campak  Bencana Non Alam dan Penyakit
# 380    518                          Difteri  Bencana Non Alam dan Penyakit
#
#      Year  Data Redundancy  Total Deaths  \
# ...

# %%
df[df['Cause'] == 'AIDS']
# Out:
#      index Cause                           Type  Year  Data Redundancy  \
# 101    112  AIDS  Bencana Non Alam dan Penyakit  2010                1
# 111    122  AIDS  Bencana Non Alam dan Penyakit  2007                1
# 113    124  AIDS  Bencana Non Alam dan Penyakit  2008                1
# 115    126  AIDS  Bencana Non Alam dan Penyakit  2006                1
# 116    127  AIDS  Bencana Non Alam dan Penyakit  2019                1
# 121    132  AIDS  Bencana Non Alam dan Penyakit  2011                1
# 129    141  AIDS  Bencana Non Alam dan Penyakit  2005                1
# 139    155  AIDS  Bencana Non Alam dan Penyakit  2004                1
# 141    157  AIDS  Bencana Non Alam dan Penyakit  2009                1
# 149    168  AIDS  Bencana Non Alam dan Penyakit  2003                1
# 195    229  AIDS  Bencana Non Alam dan Penyakit  2002                1
# 200    234  AIDS  Bencana Non Alam dan Penyakit  2001                1
# ...

# %%
pneumonia = df[df['Cause'] == 'Pneumonia']

pneumonia
# Out:
#     index      Cause                           Type  Year  Data Redundancy  \
# 55     61  Pneumonia  Bencana Non Alam dan Penyakit  2004                1
# 62     68  Pneumonia  Bencana Non Alam dan Penyakit  2005                1
# 73     80  Pneumonia  Bencana Non Alam dan Penyakit  2006                1
# 76     83  Pneumonia  Bencana Non Alam dan Penyakit  2009                1
# 91    101  Pneumonia  Bencana Non Alam dan Penyakit  2010                1
#
#     Total Deaths                                 Source Page at Source  \
# 55          3103  Profil Kesehatan Indonesia Tahun 2004             20
# 62          2765  Profil Kesehatan Indonesia Tahun 2005             21
# 73          2459  Profil Kesehatan Indonesia Tahun 2007             26
# 76          2365  Profil Kesehatan Indonesia Tahun 2009   Lampiran 3.3
# 91          1315  Profil Kesehatan Indonesia Tahun 2011   Lampiran 3.3
#
#                                            Source URL
# ...

# %%
import numpy as np

pneu_table = pd.pivot_table(pneumonia, values='Total Deaths', index='Cause', columns='Year')
pneu_table.loc['Pneumonia', 2011] = 65902
pneu_table.loc['Pneumonia', 2012] = 60467
pneu_table.loc['Pneumonia', 2013] = 0
pneu_table.loc['Pneumonia', 2014] = 52599
pneu_table.loc['Pneumonia', 2015] = 88744
pneu_table.loc['Pneumonia', 2016] = 62496
pneu_table.loc['Pneumonia', 2017] = 173887
pneu_table.loc['Pneumonia', 2018] = 40426  
pneu_table.loc['Pneumonia', 2019] = 56180  
pneu_table.loc['Pneumonia', 2020] = 49574  
pneu_table.loc['Pneumonia', 2021] = 44521
pneu_table.loc['Pneumonia', 2022] = 15157



pneu_table

pneu_table = pneu_table.sort_index(axis=1)

pneu_table = pneu_table.astype(float)

mean_value = pneu_table[pneu_table != 0].mean().mean()
pneu_table_filled = pneu_table.replace(0, np.nan).fillna(mean_value)

pneu_table_filled
# Out:
# Year         2004    2005    2006    2009    2010     2011     2012     2013  \
# Cause
# Pneumonia  3103.0  2765.0  2459.0  2365.0  1315.0  65902.0  60467.0  45122.5
#
# Year          2014     2015     2016      2017     2018     2019     2020  \
# Cause
# Pneumonia  52599.0  88744.0  62496.0  173887.0  40426.0  56180.0  49574.0
#
# Year          2021     2022
# Cause
# Pneumonia  44521.0  15157.0

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = pneu_table_filled.loc['Pneumonia', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun-tahun berikutnya
start_year = 2023
end_year = 2025
predicted_years = range(start_year, end_year + 1)

# Membuat DataFrame kosong untuk menyimpan prediksi
predicted_df_pneu = pd.DataFrame(columns=['Year', 'Deaths'])

# Mengisi DataFrame dengan prediksi
for year in predicted_years:
   predicted_deaths = regression.predict([[year]])
   predicted_df_pneu = pd.concat([predicted_df_pneu, pd.DataFrame({'Year': [year], 'Deaths': [predicted_deaths[0][0]]})], ignore_index=True)

# Menampilkan DataFrame baru
predicted_df_pneu
# Out:
#    Year        Deaths
# 0  2023  77225.302567
# 1  2024  80657.677684
# 2  2025  84090.052801

# %%
new_data = {
   'Year': [2019,2020, 2021, 2022],
   'Deaths': [56180,49574, 44521, 15157]
}
new_row = pd.DataFrame(new_data)

# Menggabungkan data baru dengan dataframe awal
predicted_df_pneu = pd.concat([predicted_df_pneu, new_row], ignore_index=True)

# Mengurutkan dataframe berdasarkan kolom 'Year'
predicted_df_pneu = predicted_df_pneu.sort_values('Year').reset_index(drop=True)

predicted_df_pneu['Cause'] = 'Pneumonia'

predicted_df_pneu
# Out:
#    Year        Deaths      Cause
# 0  2019  56180.000000  Pneumonia
# 1  2020  49574.000000  Pneumonia
# 2  2021  44521.000000  Pneumonia
# 3  2022  15157.000000  Pneumonia
# 4  2023  77225.302567  Pneumonia
# 5  2024  80657.677684  Pneumonia
# 6  2025  84090.052801  Pneumonia

# %%
tuberkulosis = df[df['Cause'] == 'Tuberkulosis']

tuberkulosis
# Out:
#     index         Cause                           Type  Year  Data Redundancy  \
# 10     14  Tuberkulosis  Bencana Non Alam dan Penyakit  2019                1
# 44     50  Tuberkulosis  Bencana Non Alam dan Penyakit  2004                1
# 80     87  Tuberkulosis  Bencana Non Alam dan Penyakit  2005                1
#
#     Total Deaths                                 Source Page at Source  \
# 10         11993  Profil Kesehatan Indonesia Tahun 2019    Lampiran 52
# 44          3852  Profil Kesehatan Indonesia Tahun 2004             20
# 80          2024  Profil Kesehatan Indonesia Tahun 2005             21
#
#                                            Source URL
# 10  https://pusdatin.kemkes.go.id/download.php?fil...
# 44  https://pusdatin.kemkes.go.id/download.php?fil...
# 80  https://pusdatin.kemkes.go.id/download.php?fil...

# %%
import numpy as np

tuber_table = pd.pivot_table(tuberkulosis, values='Total Deaths', index='Cause', columns='Year')
tuber_table.loc['Tuberkulosis', 2018] = 0 
tuber_table.loc['Tuberkulosis', 2020] = 93000  
tuber_table.loc['Tuberkulosis', 2021] = 52174
tuber_table.loc['Tuberkulosis', 2022] = 150000

tuber_table = tuber_table.sort_index(axis=1)

tuber_table = tuber_table.astype(float)

mean_value = tuber_table[tuber_table != 0].mean().mean()
tuber_table_filled = tuber_table.replace(0, np.nan).fillna(mean_value)

tuber_table_filled
# Out:
# Year            2004    2005          2018     2019     2020     2021  \
# Cause
# Tuberkulosis  3852.0  2024.0  52173.833333  11993.0  93000.0  52174.0
#
# Year              2022
# Cause
# Tuberkulosis  150000.0

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = tuber_table_filled.loc['Tuberkulosis', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun-tahun berikutnya
start_year = 2023
end_year = 2025
predicted_years = range(start_year, end_year + 1)

# Membuat DataFrame kosong untuk menyimpan prediksi
predicted_df_tuber = pd.DataFrame(columns=['Year', 'Deaths'])

# Mengisi DataFrame dengan prediksi
for year in predicted_years:
   predicted_deaths = regression.predict([[year]])
   predicted_df_tuber = pd.concat([predicted_df_tuber, pd.DataFrame({'Year': [year], 'Deaths': [predicted_deaths[0][0]]})], ignore_index=True)

# Menampilkan DataFrame baru
predicted_df_tuber
# Out:
#    Year        Deaths
# 0  2023  89162.512116
# 1  2024  94141.757337
# 2  2025  99121.002558

# %%
new_data = {
   'Year': [2019, 2020, 2021, 2022],
   'Deaths': [11993, 93000, 52174, 150000]
}
new_row = pd.DataFrame(new_data)

# Menggabungkan data baru dengan dataframe awal
predicted_df_tuber = pd.concat([predicted_df_tuber, new_row], ignore_index=True)

# Mengurutkan dataframe berdasarkan kolom 'Year'
predicted_df_tuber = predicted_df_tuber.sort_values('Year').reset_index(drop=True)

predicted_df_tuber['Cause'] = 'Tuberkulosis'

predicted_df_tuber
# Out:
#    Year         Deaths         Cause
# 0  2019   11993.000000  Tuberkulosis
# 1  2020   93000.000000  Tuberkulosis
# 2  2021   52174.000000  Tuberkulosis
# 3  2022  150000.000000  Tuberkulosis
# 4  2023   89162.512116  Tuberkulosis
# 5  2024   94141.757337  Tuberkulosis
# 6  2025   99121.002558  Tuberkulosis

# %%
cov = df[df['Cause'] == 'COVID-19']

cov
# Out:
#    index     Cause                           Type  Year  Data Redundancy  \
# 1      4  COVID-19  Bencana Non Alam dan Penyakit  2021                1
# 2      5  COVID-19  Bencana Non Alam dan Penyakit  2020                1
#
#    Total Deaths         Source Page at Source Source URL
# 1         22362  COVID19.go.id            NaN        NaN
# 2         22138  COVID19.go.id            NaN        NaN

# %%
import numpy as np

cov_table = pd.pivot_table(cov, values='Total Deaths', index='Cause', columns='Year')
cov_table.loc['COVID-19', 2019] = 22250  
cov_table.loc['COVID-19', 2022] = 22250

cov_table = cov_table.sort_index(axis=1)

cov_table = cov_table.astype(float)

mean_value = cov_table[cov_table != 0].mean().mean()
cov_table_filled = cov_table.replace(0, np.nan).fillna(mean_value)

cov_table_filled
# Out:
# Year         2019     2020     2021     2022
# Cause
# COVID-19  22250.0  22138.0  22362.0  22250.0

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = cov_table_filled.loc['COVID-19', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun-tahun berikutnya
start_year = 2023
end_year = 2025
predicted_years = range(start_year, end_year + 1)

# Membuat DataFrame kosong untuk menyimpan prediksi
predicted_df_cov = pd.DataFrame(columns=['Year', 'Deaths'])

# Mengisi DataFrame dengan prediksi
for year in predicted_years:
   predicted_deaths = regression.predict([[year]])
   predicted_df_cov = pd.concat([predicted_df_cov, pd.DataFrame({'Year': [year], 'Deaths': [predicted_deaths[0][0]]})], ignore_index=True)

# Menampilkan DataFrame baru
predicted_df_cov
# Out:
#    Year   Deaths
# 0  2023  22306.0
# 1  2024  22328.4
# 2  2025  22350.8

# %%
new_data = {
   'Year': [2019, 2020, 2021, 2022],
   'Deaths': [22250, 22138, 22362, 22250]
}
new_row = pd.DataFrame(new_data)

# Menggabungkan data baru dengan dataframe awal
predicted_df_cov = pd.concat([predicted_df_cov, new_row], ignore_index=True)

# Mengurutkan dataframe berdasarkan kolom 'Year'
predicted_df_cov = predicted_df_cov.sort_values('Year').reset_index(drop=True)

predicted_df_cov['Cause'] = 'COVID-19'

predicted_df_cov
# Out:
#    Year   Deaths     Cause
# 0  2019  22250.0  COVID-19
# 1  2020  22138.0  COVID-19
# 2  2021  22362.0  COVID-19
# 3  2022  22250.0  COVID-19
# 4  2023  22306.0  COVID-19
# 5  2024  22328.4  COVID-19
# 6  2025  22350.8  COVID-19

# %%
merged_df = pd.concat([predicted_df_cov, predicted_df_tuber, predicted_df_pneu], axis=0).reset_index(drop=True)

merged_df
# Out:
#     Year         Deaths         Cause
# 0   2019   22250.000000      COVID-19
# 1   2020   22138.000000      COVID-19
# 2   2021   22362.000000      COVID-19
# 3   2022   22250.000000      COVID-19
# 4   2023   22306.000000      COVID-19
# 5   2024   22328.400000      COVID-19
# 6   2025   22350.800000      COVID-19
# 7   2019   11993.000000  Tuberkulosis
# 8   2020   93000.000000  Tuberkulosis
# 9   2021   52174.000000  Tuberkulosis
# 10  2022  150000.000000  Tuberkulosis
# 11  2023   89162.512116  Tuberkulosis
# 12  2024   94141.757337  Tuberkulosis
# 13  2025   99121.002558  Tuberkulosis
# 14  2019   56180.000000     Pneumonia
# 15  2020   49574.000000     Pneumonia
# 16  2021   44521.000000     Pneumonia
# 17  2022   15157.000000     Pneumonia
# 18  2023   77225.302567     Pneumonia
# 19  2024   80657.677684     Pneumonia
# 20  2025   84090.052801     Pneumonia

# %%
import matplotlib.pyplot as plt


# Filter data berdasarkan penyakit
covid_df = merged_df[merged_df['Cause'] == 'COVID-19']
tb_df = merged_df[merged_df['Cause'] == 'Tuberkulosis']
pneumonia_df = merged_df[merged_df['Cause'] == 'Pneumonia']

# Mengubah nilai tahun menjadi integer
covid_df['Year'] = covid_df['Year'].astype(int)
tb_df['Year'] = tb_df['Year'].astype(int)
pneumonia_df['Year'] = pneumonia_df['Year'].astype(int)

# Menampilkan visualisasi diagram garis
plt.plot(covid_df['Year'], covid_df['Deaths'], marker='o', linestyle='-', color='salmon', label='COVID-19')
plt.plot(tb_df['Year'], tb_df['Deaths'], marker='o', linestyle='-', color='blue', label='Tuberkulosis')
plt.plot(pneumonia_df['Year'], pneumonia_df['Deaths'], marker='o', linestyle='-', color='green', label='Pneumonia')
plt.xlabel('Year')
plt.ylabel('Deaths')
plt.title('Forecasting')
plt.grid(True)
plt.legend()

plt.show()
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_28572\3135821712.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_df['Year'] = covid_df['Year'].astype(int)
# C:\Users\indra\AppData\Local\Temp\ipykernel_28572\3135821712.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_df['Year'] = tb_df['Year'].astype(int)
# C:\Users\indra\AppData\Local\Temp\ipykernel_28572\3135821712.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
aids = df[df['Cause'] == 'AIDS']

aids
# Out:
#      index Cause                           Type  Year  Data Redundancy  \
# 101    112  AIDS  Bencana Non Alam dan Penyakit  2010                1
# 111    122  AIDS  Bencana Non Alam dan Penyakit  2007                1
# 113    124  AIDS  Bencana Non Alam dan Penyakit  2008                1
# 115    126  AIDS  Bencana Non Alam dan Penyakit  2006                1
# 116    127  AIDS  Bencana Non Alam dan Penyakit  2019                1
# 121    132  AIDS  Bencana Non Alam dan Penyakit  2011                1
# 129    141  AIDS  Bencana Non Alam dan Penyakit  2005                1
# 139    155  AIDS  Bencana Non Alam dan Penyakit  2004                1
# 141    157  AIDS  Bencana Non Alam dan Penyakit  2009                1
# 149    168  AIDS  Bencana Non Alam dan Penyakit  2003                1
# 195    229  AIDS  Bencana Non Alam dan Penyakit  2002                1
# 200    234  AIDS  Bencana Non Alam dan Penyakit  2001                1
# ...

# %%
import numpy as np
aids_table = pd.pivot_table(aids, values='Total Deaths', index='Cause', columns='Year')
aids_table.loc['AIDS', 2020] = 357  
aids_table.loc['AIDS', 2021] = 241  
aids_table.loc['AIDS', 2022] = 0


# Mengurutkan kolom berdasarkan tahun
aids_table = aids_table.sort_index(axis=1)

# Mengubah tipe data menjadi float
aids_table = aids_table.astype(float)

# Mengisi missing value yang berupa nilai 0 dengan rata-rata
mean_value = aids_table[aids_table != 0].mean().mean()  # Mengambil rata-rata dari nilai yang bukan 0
aids_table_filled = aids_table.replace(0, np.nan).fillna(mean_value)

aids_table_filled
# Out:
# Year   2000  2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# Cause
# AIDS   47.0  99.0  100.0  261.0  361.0  509.0  635.0  788.0  711.0  331.0
#
# Year    2010   2011   2019   2020   2021   2022
# Cause
# AIDS   979.0  597.0  614.0  357.0  241.0  442.0

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = aids_table_filled.loc['AIDS', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun-tahun berikutnya
start_year = 2023
end_year = 2025
predicted_years = range(start_year, end_year + 1)

# Membuat DataFrame kosong untuk menyimpan prediksi
predicted_df = pd.DataFrame(columns=['Year', 'Deaths'])

# Mengisi DataFrame dengan prediksi
for year in predicted_years:
   predicted_deaths = regression.predict([[year]])
   predicted_df = pd.concat([predicted_df, pd.DataFrame({'Year': [year], 'Deaths': [predicted_deaths[0][0]]})], ignore_index=True)

# Menampilkan DataFrame baru
predicted_df
# Out:
#    Year      Deaths
# 0  2023  568.907655
# 1  2024  578.137303
# 2  2025  587.366950

# %%
new_data = {
   'Year': [2019,2020, 2021, 2022],
   'Deaths': [614,357, 241, 442]
}
new_row = pd.DataFrame(new_data)

# Menggabungkan data baru dengan dataframe awal
predicted_df = pd.concat([predicted_df, new_row], ignore_index=True)

# Mengurutkan dataframe berdasarkan kolom 'Year'
predicted_df = predicted_df.sort_values('Year').reset_index(drop=True)

predicted_df
# Out:
#    Year      Deaths
# 0  2019  614.000000
# 1  2020  357.000000
# 2  2021  241.000000
# 3  2022  442.000000
# 4  2023  568.907655
# 5  2024  578.137303
# 6  2025  587.366950

# %%
import matplotlib.pyplot as plt

# Mengubah nilai tahun menjadi integer
predicted_df['Year'] = predicted_df['Year'].astype(int)

# Menampilkan visualisasi diagram garis
plt.plot(predicted_df['Year'], predicted_df['Deaths'], marker='o', linestyle='-', color='salmon')
plt.xlabel('Year')
plt.ylabel('Deaths')
plt.title('Prediksi Kematian dari penyakit AIDS')
plt.grid(True)

# Menghilangkan angka 2022.5 pada sumbu x
plt.xticks(predicted_df['Year'])

plt.show()

# %%
dbd = df[(df['Cause'] == 'Demam Berdarah')]

dbd
# Out:
#      index           Cause                           Type  Year  \
# 86      96  Demam Berdarah  Bencana Non Alam dan Penyakit  2007
# 87      97  Demam Berdarah  Bencana Non Alam dan Penyakit  2016
# 89      99  Demam Berdarah  Bencana Non Alam dan Penyakit  2009
# 95     106  Demam Berdarah  Bencana Non Alam dan Penyakit  2006
# 96     107  Demam Berdarah  Bencana Non Alam dan Penyakit  2008
# 97     108  Demam Berdarah  Bencana Non Alam dan Penyakit  2015
# 105    116  Demam Berdarah  Bencana Non Alam dan Penyakit  2019
# 106    117  Demam Berdarah  Bencana Non Alam dan Penyakit  2014
# 107    118  Demam Berdarah  Bencana Non Alam dan Penyakit  2013
# 109    120  Demam Berdarah  Bencana Non Alam dan Penyakit  2012
# 122    133  Demam Berdarah  Bencana Non Alam dan Penyakit  2011
# 131    144  Demam Berdarah  Bencana Non Alam dan Penyakit  2017
# 132    146  Demam Berdarah  Bencana Non Alam dan Penyakit  2018
# 207    244  Demam Berdarah  Bencana Non Alam dan Penyakit  2005
#
# ...

# %%
dbd_table = pd.pivot_table(dbd, values='Total Deaths', index='Cause', columns='Year')
dbd_table.loc['Demam Berdarah', 2010] = 1358
dbd_table.loc['Demam Berdarah', 2020] = 661
dbd_table.loc['Demam Berdarah', 2021] = 705
dbd_table.loc['Demam Berdarah', 2022] = 1237

dbd_table = dbd_table.sort_index(axis=1)

dbd_table = dbd_table.astype(int)

dbd_table
# Out:
# Year            2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# Cause
# Demam Berdarah    91  1196  1599  1187  1420  1358   597   816   871   907
#
# Year            2015  2016  2017  2018  2019  2020  2021  2022
# Cause
# Demam Berdarah  1215  1598   493   467   919   661   705  1237

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = dbd_table.loc['Demam Berdarah', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun-tahun berikutnya
start_year = 2023
end_year = 2028
predicted_years = range(start_year, end_year + 1)

# Membuat DataFrame kosong untuk menyimpan prediksi
predicted_df = pd.DataFrame(columns=['Year', 'Deaths'])

# Mengisi DataFrame dengan prediksi
for year in predicted_years:
    predicted_deaths = regression.predict([[year]])
    predicted_df = pd.concat([predicted_df, pd.DataFrame({'Year': [year], 'Deaths': [predicted_deaths[0][0]]})], ignore_index=True)

# Menampilkan DataFrame baru
predicted_df
# Out:
#    Year      Deaths
# 0  2023  851.215686
# 1  2024  839.431373
# 2  2025  827.647059
# 3  2026  815.862745
# 4  2027  804.078431
# 5  2028  792.294118

# %%
new_data = {
   'Year': [2019,2020, 2021, 2022],
   'Deaths': [614,357, 241, 442]
}
new_row = pd.DataFrame(new_data)

# Menggabungkan data baru dengan dataframe awal
predicted_df = pd.concat([predicted_df, new_row], ignore_index=True)

# Mengurutkan dataframe berdasarkan kolom 'Year'
predicted_df = predicted_df.sort_values('Year').reset_index(drop=True)

predicted_df
# Out:
#    Year      Deaths
# 0  2019  614.000000
# 1  2020  357.000000
# 2  2021  241.000000
# 3  2022  442.000000
# 4  2023  851.215686
# 5  2024  839.431373
# 6  2025  827.647059
# 7  2026  815.862745
# 8  2027  804.078431
# 9  2028  792.294118

# %%
import matplotlib.pyplot as plt

# Mengubah nilai tahun menjadi integer
predicted_df['Year'] = predicted_df['Year'].astype(int)

# Menampilkan visualisasi diagram garis
plt.plot(predicted_df['Year'], predicted_df['Deaths'], marker='o', linestyle='-', color='salmon')
plt.xlabel('Year')
plt.ylabel('Deaths')
plt.title('Prediksi Kematian dari penyakit Demam Berdarah')
plt.grid(True)

# Menghilangkan angka 2022.5 pada sumbu x
plt.xticks(predicted_df['Year'])

plt.show()

# %%
table = pd.pivot_table(df, values='Total Deaths', index='Cause', columns='Year')

table.fillna(method='ffill', inplace=True)

table
# Out:
# Year                           2000   2001   2002   2003    2004    2005  \
# Cause
# AIDS                           47.0   99.0  100.0  261.0   361.0   509.0
# Antraks                        47.0    2.0    8.0    2.0     8.0     2.0
# Avian Influenza (Flu Burung)   47.0    2.0    8.0    2.0     8.0    13.0
# Batuk Rejan                    47.0    2.0    8.0    2.0     4.0    13.0
# COVID-19                       47.0    2.0    8.0    2.0     4.0    13.0
# ...                             ...    ...    ...    ...     ...     ...
# TB Paru BTA Positif           109.0   23.0   21.0   10.0  4215.0  4692.0
# Tetanus                       109.0   23.0   21.0   10.0  4215.0    43.0
# Tetanus Neonatal              109.0   23.0   21.0   10.0    39.0    43.0
# Tetanus Neonatorium           183.0  100.0   91.0   98.0    42.0    82.0
# Tuberkulosis                  183.0  100.0   91.0   98.0  3852.0  2024.0
#
# Year                            2006     2007    2008    2009  ...   2012  \
# ...

# %%
# Mean
table_filled_mean = table.fillna(table.mean())

table_filled_mean
# Out:
# Year                           2000   2001   2002   2003    2004    2005  \
# Cause
# AIDS                           47.0   99.0  100.0  261.0   361.0   509.0
# Antraks                        47.0    2.0    8.0    2.0     8.0     2.0
# Avian Influenza (Flu Burung)   47.0    2.0    8.0    2.0     8.0    13.0
# Batuk Rejan                    47.0    2.0    8.0    2.0     4.0    13.0
# COVID-19                       47.0    2.0    8.0    2.0     4.0    13.0
# ...                             ...    ...    ...    ...     ...     ...
# TB Paru BTA Positif           109.0   23.0   21.0   10.0  4215.0  4692.0
# Tetanus                       109.0   23.0   21.0   10.0  4215.0    43.0
# Tetanus Neonatal              109.0   23.0   21.0   10.0    39.0    43.0
# Tetanus Neonatorium           183.0  100.0   91.0   98.0    42.0    82.0
# Tuberkulosis                  183.0  100.0   91.0   98.0  3852.0  2024.0
#
# Year                            2006     2007    2008    2009  ...  \
# ...

# %%
# K-NN Imputation
from sklearn.impute import KNNImputer

k = 7
imputer = KNNImputer(n_neighbors=k)
table_interpolated = imputer.fit_transform(table)
table_filled_knn= pd.DataFrame(table_interpolated, index=table.index, columns=table.columns)
table_filled_knn
# Out:
# Year                           2000   2001   2002   2003    2004    2005  \
# Cause
# AIDS                           47.0   99.0  100.0  261.0   361.0   509.0
# Antraks                        47.0    2.0    8.0    2.0     8.0     2.0
# Avian Influenza (Flu Burung)   47.0    2.0    8.0    2.0     8.0    13.0
# Batuk Rejan                    47.0    2.0    8.0    2.0     4.0    13.0
# COVID-19                       47.0    2.0    8.0    2.0     4.0    13.0
# ...                             ...    ...    ...    ...     ...     ...
# TB Paru BTA Positif           109.0   23.0   21.0   10.0  4215.0  4692.0
# Tetanus                       109.0   23.0   21.0   10.0  4215.0    43.0
# Tetanus Neonatal              109.0   23.0   21.0   10.0    39.0    43.0
# Tetanus Neonatorium           183.0  100.0   91.0   98.0    42.0    82.0
# Tuberkulosis                  183.0  100.0   91.0   98.0  3852.0  2024.0
#
# Year                            2006     2007    2008    2009  ...  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = table_filled_mean.loc['AIDS', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun berikutnya
next_year = 2022
predicted_deaths = regression.predict([[next_year]])
print("Prediksi jumlah kematian AIDS di tahun {next_year}: {predicted_deaths[0][0]}")
# Out:
# Prediksi jumlah kematian AIDS di tahun {next_year}: {predicted_deaths[0][0]}

# %%
from sklearn.linear_model import LinearRegression

# Mengambil data tahun dan jumlah kematian AIDS
data = table_filled_knn.loc['Demam Berdarah', :].dropna()
years = data.index.values.reshape(-1, 1)
deaths = data.values.reshape(-1, 1)

# Membuat model regresi linier
regression = LinearRegression()
regression.fit(years, deaths)

# Prediksi jumlah kematian AIDS di tahun-tahun berikutnya
start_year = 2022
end_year = 2026
predicted_years = range(start_year, end_year + 1)

# Membuat DataFrame kosong untuk menyimpan prediksi
predicted_df = pd.DataFrame(columns=['Year', 'Deaths'])

# Mengisi DataFrame dengan prediksi
for year in predicted_years:
   predicted_deaths = regression.predict([[year]])
   predicted_df = pd.concat([predicted_df, pd.DataFrame({'Year': [year], 'Deaths': [predicted_deaths[0][0]]})], ignore_index=True)

# Menampilkan DataFrame baru
predicted_df
# Out:
#    Year        Deaths
# 0  2022   8693.090909
# 1  2023   9215.877470
# 2  2024   9738.664032
# 3  2025  10261.450593
# 4  2026  10784.237154

# %%
import matplotlib.pyplot as plt

# Mengubah nilai tahun menjadi integer
predicted_df['Year'] = predicted_df['Year'].astype(int)

# Menampilkan visualisasi diagram garis
plt.plot(predicted_df['Year'], predicted_df['Deaths'], marker='o', linestyle='-', color='salmon')
plt.xlabel('Year')
plt.ylabel('Deaths')
plt.title('Prediksi Kematian dari penyakit Demam Berdarah')
plt.grid(True)

# Menghilangkan angka 2022.5 pada sumbu x
plt.xticks(predicted_df['Year'])

plt.show()

# %%
df_pivot = pd.melt(table_filled_knn.reset_index(), id_vars=['Cause'], value_vars=table_filled_mean.columns, var_name='Year', value_name='Total Deaths')

df_pivot
# Out:
#                              Cause  Year  Total Deaths
# 0                             AIDS  2000          47.0
# 1                          Antraks  2000          47.0
# 2     Avian Influenza (Flu Burung)  2000          47.0
# 3                      Batuk Rejan  2000          47.0
# 4                         COVID-19  2000          47.0
# ...                            ...   ...           ...
# 2019           TB Paru BTA Positif  2021       22362.0
# 2020                       Tetanus  2021       22362.0
# 2021              Tetanus Neonatal  2021       22362.0
# 2022           Tetanus Neonatorium  2021       22362.0
# 2023                  Tuberkulosis  2021       22362.0
#
# [2024 rows x 3 columns]

# %%
df_pivot['Cause'].unique()
# Out:
# array(['AIDS', 'Antraks', 'Avian Influenza (Flu Burung)', 'Batuk Rejan',
#        'COVID-19', 'Campak',
#        'Cedera YDT lainnya YTT dan daerah badan Multipel',
#        'Cedera intrakranial', 'Cedera lahir',
#        'Cedera, Keracunan, dan Akibat Sebab Luar Tertentu Lainnya',
#        'Demam Berdarah', 'Demam Tifoid dan Paratifoid',
#        'Demam yang Sebabnya Tidak Diketahui', 'Dengue High Fever',
#        'Dengue Shock Syndrome', 'Diabetes melitus YTT', 'Diare',
#        'Difteri', 'Dispepsia', 'Eklamsia dan preeklamsia',
#        'Faktor yg Mempengaruhi Keadaan Kesehatan & yg Berhubungan dengan Pelayanan Kesehatan',
#        'Gagal ginjal lainnya', 'Gangguan Mental & Perilaku',
#        'Gangguan saluran napas lainnya yang berhubungan dengan masa perinatal',
#        'Gastritis dan Duodenitis', 'Gastroenteritis',
#        'Gejala, Tanda & Penemuan Laboratorium, Klinik Abnormal YTK',
#        'Gizi Buruk', 'Hepatitis', 'Hepatitis B', 'Hepatitis Klinis',
# ...

# %%
infectious_disease = ['AIDS', 'Antraks', 'Avian Influenza (Flu Burung)', 'Batuk Rejan', 'Campak', 'Cikungunya', 'COVID-19', 'Demam Tifoid dan Paratifoid', 
                     'Difteri', 'Gastroenteritis', 'Hepatitis A', 'Hepatitis B', 'Malaria', 'Leptospirosis', 'Rabies', 'Rubella', 'Tuberkulosis', 
                     'Demam Berdarah', 'Disentri', 'Frambusia', 'Malaria', 'Meningitis', 'Parotitis', 'Pertusis', 'Polio', 'Thypoid', 'Tifus Perut', 'Kolera', 'Leptospirosis',
                     'Penyakit Infeksi & Parasit Tertentu', 'Penyakit infeksi dan parasit kongenital', 'Penyakit Sistem Cerna', 'Penyakit Sistem Kemih Kelamin', 'Penyakit Sistem Napas',
                     'Rabies', 'Rubella', 'Tuberkulosis', 'TB Paru BTA Positif', 'Pneumonia'
                     ]

def kategori_penyakit(penyakit):
   if penyakit in infectious_disease:
      return 'Penyakit Menular'
   else:
      return 'Penyakit Lainnya'
   
df_pivot['Category'] = [kategori_penyakit(p) for p in df_pivot['Cause']]

df_pivot
# Out:
#                              Cause  Year  Total Deaths          Category
# 0                             AIDS  2000          47.0  Penyakit Menular
# 1                          Antraks  2000          47.0  Penyakit Menular
# 2     Avian Influenza (Flu Burung)  2000          47.0  Penyakit Menular
# 3                      Batuk Rejan  2000          47.0  Penyakit Menular
# 4                         COVID-19  2000          47.0  Penyakit Menular
# ...                            ...   ...           ...               ...
# 2019           TB Paru BTA Positif  2021       22362.0  Penyakit Menular
# 2020                       Tetanus  2021       22362.0  Penyakit Lainnya
# 2021              Tetanus Neonatal  2021       22362.0  Penyakit Lainnya
# 2022           Tetanus Neonatorium  2021       22362.0  Penyakit Lainnya
# 2023                  Tuberkulosis  2021       22362.0  Penyakit Menular
#
# [2024 rows x 4 columns]

# %%
df_pivot[df_pivot['Cause'] == 'Tuberkulosis']
# Out:
#              Cause  Year  Total Deaths          Category
# 91    Tuberkulosis  2000         183.0  Penyakit Menular
# 183   Tuberkulosis  2001         100.0  Penyakit Menular
# 275   Tuberkulosis  2002          91.0  Penyakit Menular
# 367   Tuberkulosis  2003          98.0  Penyakit Menular
# 459   Tuberkulosis  2004        3852.0  Penyakit Menular
# 551   Tuberkulosis  2005        2024.0  Penyakit Menular
# 643   Tuberkulosis  2006          46.0  Penyakit Menular
# 735   Tuberkulosis  2007          74.0  Penyakit Menular
# 827   Tuberkulosis  2008         100.0  Penyakit Menular
# 919   Tuberkulosis  2009          76.0  Penyakit Menular
# 1011  Tuberkulosis  2010          84.0  Penyakit Menular
# 1103  Tuberkulosis  2011          69.0  Penyakit Menular
# 1195  Tuberkulosis  2012          59.0  Penyakit Menular
# 1287  Tuberkulosis  2013          42.0  Penyakit Menular
# 1379  Tuberkulosis  2014          54.0  Penyakit Menular
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group dan hitung total kematian berdasarkan kategori
per_category = df_pivot.groupby(['Category'])['Total Deaths'].sum()

# Plot donut chart
plt.figure(figsize=(8, 6))
sns.set_palette('pastel')
plt.pie(per_category, labels=per_category.index, autopct='%1.0f%%', startangle=90)

# Buat lingkaran di tengah untuk membuat donut chart
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Atur aspek ratio menjadi equal untuk menjaga lingkaran menjadi bentuk donut
plt.axis('equal')
plt.title('Total Kematian Berdasarkan Kategori', fontsize=15)
plt.show()

# %%
df_pivot_infectious_disease = df_pivot[df_pivot['Category'] == 'Penyakit Menular']

df_pivot_infectious_disease
# Out:
#                              Cause  Year  Total Deaths          Category
# 0                             AIDS  2000          47.0  Penyakit Menular
# 1                          Antraks  2000          47.0  Penyakit Menular
# 2     Avian Influenza (Flu Burung)  2000          47.0  Penyakit Menular
# 3                      Batuk Rejan  2000          47.0  Penyakit Menular
# 4                         COVID-19  2000          47.0  Penyakit Menular
# ...                            ...   ...           ...               ...
# 2012                     Pneumonia  2021       22362.0  Penyakit Menular
# 2013                         Polio  2021       22362.0  Penyakit Menular
# 2014                        Rabies  2021       22362.0  Penyakit Menular
# 2019           TB Paru BTA Positif  2021       22362.0  Penyakit Menular
# 2023                  Tuberkulosis  2021       22362.0  Penyakit Menular
#
# [506 rows x 4 columns]

# %%
direct_contact = ['AIDS', 'Hepatitis A', 'Hepatitis B', 'Disentri', 'Frambusia', 'Meningitis', 'Pertusis', 'Penyakit infeksi dan parasit kongenital', 'Penyakit Sistem Kemih Kelamin']
food = ['Demam Tifoid dan Paratifoid', 'Gastroenteritis', 'Leptospirosis', 'Thypoid', 'Tifus Perut', 'Kolera', 'Penyakit Sistem Cerna','Polio']
droplet = ['Antraks', 'Avian Influenza (Flu Burung)', 'Batuk Rejan', 'Campak', 'COVID-19', 'Difteri', 'Influenza', 'Parotitis', 'Penyakit Infeksi & Parasit Tertentu', 'Penyakit Sistem Napas', 'Rubella', 'Tuberkulosis', 'TB Paru BTA Positif', 'Pneumonia']
vektor = ['Cikungunya', 'Demam Berdarah', 'Malaria', 'Rabies']

def penyebaran_penyakit(penyakit):
   if penyakit in direct_contact:
      return 'Kontak Langsung'
   elif penyakit in food:
      return 'Makanan'
   elif penyakit in droplet:
      return 'Droplet'
   elif penyakit in vektor:
      return 'Vektor'
   
df_pivot_infectious_disease['Jenis Penyebaran'] = [penyebaran_penyakit(p) for p in df_pivot_infectious_disease['Cause']]

df_pivot_infectious_disease
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_28572\1858511221.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_infectious_disease['Jenis Penyebaran'] = [penyebaran_penyakit(p) for p in df_pivot_infectious_disease['Cause']]
#                              Cause  Year  Total Deaths          Category  \
# 0                             AIDS  2000          47.0  Penyakit Menular
# 1                          Antraks  2000          47.0  Penyakit Menular
# 2     Avian Influenza (Flu Burung)  2000          47.0  Penyakit Menular
# 3                      Batuk Rejan  2000          47.0  Penyakit Menular
# 4                         COVID-19  2000          47.0  Penyakit Menular
# ...

# %%
per_penyebaran = df_pivot_infectious_disease.groupby(['Jenis Penyebaran'])['Total Deaths'].sum()

# Plot pie chart
plt.figure(figsize=(8, 6))
sns.set_palette('pastel')
plt.pie(per_penyebaran, labels=per_penyebaran.index, autopct='%1.2f%%', startangle=90)

# Atur aspek ratio menjadi equal untuk menjaga pie chart menjadi lingkaran sempurna
plt.axis('equal')

# Tambahkan judul
plt.title('Total Kematian Penyakit Menular Berdasarkan Jenis Penyebaran', fontsize=15)

# Tampilkan plot
plt.show()

# %%
df_selected = df_pivot_infectious_disease.loc[(df_pivot_infectious_disease['Year'] >= 2019) & (df_pivot_infectious_disease['Year'] <= 2021) & (df_pivot_infectious_disease['Cause'] != 'COVID-19')]

z = df_selected.groupby(['Cause'])['Total Deaths'].sum().sort_values(ascending=False).head(5)

b = df_selected[(df_selected['Cause'] == 'AIDS') | (df_selected['Cause'] == 'Penyakit Sistem Cerna') | (df_selected['Cause'] == 'Tuberkulosis') | (df_selected['Cause'] == 'Avian Influenza (Flu Burung)') | (df_selected['Cause'] == 'Demam Berdarah')]

# %%
a = b.pivot_table(index='Cause', columns='Year', values='Total Deaths')

# Create a bar chart for each disease and year
a.plot(kind='bar', width=0.8)
plt.title('Total Kematian Penyakit Menular 3 Tahun Terakhir', fontsize=15)
plt.xlabel('Disease')
plt.ylabel('Total Deaths')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
